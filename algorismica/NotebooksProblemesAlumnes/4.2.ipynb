# %% [markdown]
# # Capítol 4 - Algorismes i Text

# %% [markdown]
# ### 4.2 Alfabet aviació

# %% [markdown]
# Alfabet d'aviació:
# |   |   |   |   |   |
# |---|---|---|---|---|
# | A | B | C | D | E |
# | Alpha | Bravo | Charlie | Delta | Echo |
# | F | G | H | I | J |
# | Foxtrot | Golf | Hotel | India | Juliet |
# | K | L | M | N | O |
# | Kilo | Lima | Mike | November | Oscar |
# | P | Q | R | S | T |
# | Papa | Quebec | Romeo | Sierra | Tango |
# | U | V | W | X | Y |
# | Uniform | Victor | Whiskey | X-ray | Yankee |
# | Z |   |   |   |   |
# | Zulu |   |   |   |   |
#
#
# Escriu una funció que, usant un diccionari, converteixi una cadena de lletres a l'alfabet d'aviació, genenrat una llista de sortida.

# %%
def aviacio(cadena):
    """
    Aquesta funció converteix una cadena d'entrada a l'alfabet fonètic.
    
    Parameters
    ----------
    cadena: string
    
    Returns
    -------
    traduccio: string
    """
    return traduccio

# %%
assert aviacio('YtH') == ['Yankee', 'Tango', 'Hotel']
