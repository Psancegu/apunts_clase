# %% [markdown]
# # Capítol 2 - Algorismes bàsics de Python

# %% [markdown]
# ### 2.13  Nombres perfectes

# %% [markdown]
# Un nombre enter positiu és perfecte si és la suma dels seus divisors positius i menors que ell mateix (i.e. divisors propis). Escriu una funció que determini si un nombre és perfecte o no, retornant un valor booleà.

# %%
def perfecte(num):
    suma_divisors = 0
    for i in range(1,int(num/2)+1):
        if num % i == 0:
            suma_divisors += i
    
    if suma_divisors == num:
        return True
    else:
        return False

    """
    Aquesta funció comprova si un nombre es perfecte.
    
    Parameters
    ----------
    num: int
        El número que es vol comprovar
    
    Returns
    -------
    b: bool
        Si el nombre d'entrada és un nombre perfecte
    
    """

# %%
assert perfecte(28) == True
assert perfecte(6) == True
assert perfecte(8) == False
