# %% [markdown]
# # Capítol 2 - Algorismes bàsics de Python

# %% [markdown]
# ### 2.16  Nombres ambiciosos

# %% [markdown]
# Un nombre és ambiciós si la suma dels seus factors és, quan apliquem recursivament aquesta definició, un nombre perfecte. Per exemple, 95:
# + Els seus divisors propis són 1, 5 i 19. La seva suma és 25.
# + Els divisors propis de 25 són 1 i 5. La seva suma és 6.
# + 6 és un nombre perfecte.
#
# Escriu una funció que determini si un nombre és ambiciós.

# %%
def ambicios(num):
    b = False
    def suma_divisors(n):
        """Retorna la suma dels divisors propis d'un nombre n."""
        suma = 0
        for i in range(1, n // 2 + 1):
            if n % i == 0:
                suma += i
        return suma
    
    def es_nombre_perfecte(n):
        """Comprova si un nombre n és perfecte."""
        return n == suma_divisors(n)

    suma = suma_divisors(num)
    
    while not es_nombre_perfecte(suma):
        suma_divisors(suma)
        b = False
        
    
    return True

# Exemple d'ús
print(ambicios(25))  # Ha de retornar True
print(ambicios(95))  # Ha de retornar True

        
    
    

"""
    Aquesta funció comprova si un nombre es ambiciós.
    
    Parameters
    ----------
    num: int
        El número que es vol comprovar
    
    Returns
    -------
    b: bool
        Si el nombre d'entrada és un nombre ambiciós
    
"""
# Out:
# True
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 3378, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_22952/2488540353.py", line 26, in <module>
#     print(ambicios(95))  # Ha de retornar True
#           ^^^^^^^^^^^^
#   File "/tmp/ipykernel_22952/2488540353.py", line 17, in ambicios
#     while not es_nombre_perfecte(suma):
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_22952/2488540353.py", line 13, in es_nombre_perfecte
#     return n == suma_divisors(n)
#                 ^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_22952/2488540353.py", line -1, in suma_divisors
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 1997, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/IPython/core/ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/IPython/core/ultratb.py", line 1006, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/IPython/core/ultratb.py", line 859, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/IPython/core/ultratb.py", line 812, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#                   ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/IPython/core/ultratb.py", line 730, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#                                               ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "/usr/lib/python3/dist-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
assert ambicios(25) == True  
assert ambicios(100) == False 
assert ambicios(143) == True

# %%
def ambicios_recursiu(num):
    """
    Aquesta funció comprova si un nombre es ambiciós.
    Implementació recursiva
    
    Parameters
    ----------
    num: int
        El número que es vol comprovar
    
    Returns
    -------
    b: bool
        Si el nombre d'entrada és un nombre ambiciós
    
    """
    return b

# %%
assert ambicios_recursiu(25) == True  
assert ambicios_recursiu(100) == False 
assert ambicios_recursiu(143) == True
