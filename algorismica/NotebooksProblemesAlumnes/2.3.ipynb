# %% [markdown]
# # Capítol 2 - Algorismes bàsics de Python

# %% [markdown]
# ### 2.3 Condicionals

# %% [markdown]
# Escriu una funció que donat un nombre de cerveses i un booleà que indiqui si és cap de setmana o no, retorni una cadena de caràcters que expliquin si la festa serà un èxit o no. Considera que per tenir èxit hi ha d'haver entre 50 i 100 cerveses, excepte si és cap de setmana que no hi ha límit.

# %%
def prou_cerveses(numCerveses, esCapDeSetmana):
    """
    Aquest programa prediu com anirà la festa en funció de les cerveses.
    
    Parameters
    ----------
    numCerveses: int
    esCapDeSetmana: bool
       
    Returns
    -------
    None
    """

# %%
assert prou_cerveses(75, False) == 'Éxit'
assert prou_cerveses(75, False) == 'Éxit'
assert prou_cerveses(125, False) == 'Fracàs'
assert prou_cerveses(125, True) == 'Éxit'
assert prou_cerveses(25, False) == 'Fracàs'
assert prou_cerveses(25, True) == 'Fracàs'

# %% [markdown]
# Escriu una funció que retorni la qualificació qualitativa d'un alumne donada la seva nota numèrica. Les qualificacions són les següents:
# + Suspès: nota menor que 5
# + Aprovat: igual o major a 5 i menor a 7
# + Notable: igual o major a 7 i menor a 9
# + Excel·lent: igual o major a 9 i menor a 10
# + Matrícula d'honor: 10

# %%
def nota(num):
    """
    Aquesta funció retorna la qualificació d'un alumne.
    
    Parameters
    ----------
    num: float
       
    Returns
    -------
    qualificació: string
    """

    return qualificacio

# %%
assert nota(0.9) == 'Suspès'
assert nota(5.9) == 'Aprovat'
assert nota(7.9) == 'Notable'
assert nota(9.9) == 'Excel·lent'
assert nota(10) == 'Matrícula d\'honor'
