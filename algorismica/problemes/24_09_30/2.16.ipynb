# %% [markdown]
# # Capítol 2 - Algorismes bàsics de Python

# %% [markdown]
# ### 2.16  Nombres ambiciosos

# %% [markdown]
# Un nombre és ambiciós si la suma dels seus factors és, quan apliquem recursivament aquesta definició, un nombre perfecte. Per exemple, 95:
# + Els seus divisors propis són 1, 5 i 19. La seva suma és 25.
# + Els divisors propis de 25 són 1 i 5. La seva suma és 6.
# + 6 és un nombre perfecte.
#
# Escriu una funció que determini si un nombre és ambiciós.

# %%
'''
def ambicios(num):
    b = False
    k = 0
    while b == False and k < 2:
        suma_divisors = 0
        for i in obtenir_divisors(num):
            suma_divisors += i
        print(suma_divisors)
        if suma_divisors != 6:
            num = suma_divisors
            k += 1
            continue
        else:
            b = True
            break
    return b
'''
    
def funcio_perfecte(nombre):
    llista_divisors = []
    suma_divisors = 0
    for i in range(1,int(nombre)):
        if nombre % i == 0:
            llista_divisors.append(i)
    for i in llista_divisors:
            suma_divisors += i
            
        
    
    return llista_divisors

funcio_perfecte(33)
    
"""
Aquesta funció comprova si un nombre es ambiciós.

Parameters
----------
num: int
    El número que es vol comprovar

Returns
-------
b: bool
    Si el nombre d'entrada és un nombre ambiciós

"""
# Out:
# "\nAquesta funció comprova si un nombre es ambiciós.\n\nParameters\n----------\nnum: int\n    El número que es vol comprovar\n\nReturns\n-------\nb: bool\n    Si el nombre d'entrada és un nombre ambiciós\n\n"

# %%
# Següent numero Perfecte

def funcio_perfecte(num):
    perfecte = False
    for i in obtenir_divisors(num):
        suma_divisors += i

# %%
assert ambicios(25) == True  
assert ambicios(100) == False 
assert ambicios(143) == True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 assert ambicios(25) == True
#       2 assert ambicios(100) == False
#       3 assert ambicios(143) == True
#
# NameError: name 'ambicios' is not defined

# %%
def ambicios_recursiu(num):
    """
    Aquesta funció comprova si un nombre es ambiciós.
    Implementació recursiva
    
    Parameters
    ----------
    num: int
        El número que es vol comprovar
    
    Returns
    -------
    b: bool
        Si el nombre d'entrada és un nombre ambiciós
    
    """
    return b

# %%
assert ambicios_recursiu(25) == True  
assert ambicios_recursiu(100) == False 
assert ambicios_recursiu(143) == True
